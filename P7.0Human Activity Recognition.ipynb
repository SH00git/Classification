# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data = pd.read_csv(r"C:\Users\hornt\Documents\03.PROJECTS -\01. Datasets\P7.0Human_Activity_Recognition_Data.csv")
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %% [markdown]
# ### Data Description

# %%
print(data.shape)
data.columns
# Out:
# (2947, 563)
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
plt.figure(figsize=(6,4))
data.Activity.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Activity'>

# %%
data.describe(include='all')
# Out:
#         tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count         2947.000000        2947.000000        2947.000000
# unique                NaN                NaN                NaN
# top                   NaN                NaN                NaN
# freq                  NaN                NaN                NaN
# mean             0.273996          -0.017863          -0.108386
# std              0.060570           0.025745           0.042747
# min             -0.592004          -0.362884          -0.576184
# 25%              0.262075          -0.024961          -0.121162
# 50%              0.277113          -0.016967          -0.108458
# 75%              0.288097          -0.010143          -0.097123
# max              0.671887           0.246106           0.494114
#
#         tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# count        2947.000000       2947.000000       2947.000000
# unique               NaN               NaN               NaN
# ...

# %%
sns.heatmap(data.isna(),cbar =False)
#hence no null values
# Out:
# <Axes: >

# %% [markdown]
# ### Pre-processing

# %%
dict_replace = dict(zip(list(data['Activity'].unique()),[1,2,3,4,5,6]))

# %%
data['Activity'] = data['Activity'].map(dict_replace)
data['Activity'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ### Importing Sklearn Libraries

# %%
########### DATA SCALING / NORMALISATION #################
from sklearn.preprocessing import StandardScaler,MinMaxScaler


################  MODEL SELECTION   ######################
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import KFold # for cross validation
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV  # Randomized search on hyper parameters.

# Feature Selection Libraries
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectFromModel

###############  MODEL BUILDING FUNCTIONS  ################

## gradient descent based classification algorithms
from sklearn.linear_model import LogisticRegression

### ensemble based classification algorithms
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier

## distance based classification algorithms
from sklearn.neighbors import KNeighborsClassifier #KNN#

## Tree based classification algorithms 
from sklearn.tree import DecisionTreeClassifier#
from sklearn.ensemble import ExtraTreesClassifier


################# EVALUATION METRICS #####################
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score, log_loss
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve, auc

# %% [markdown]
# ### Feature Engineering

# %%
## Splitting training Columns 
X =data.iloc[:,:-2]
y =data['Activity']

# %%
from sklearn.decomposition import PCA
pca = PCA()
X = pca.fit_transform(X)
pca.get_covariance()
explained_variance=pca.explained_variance_ratio_
explained_variance.shape[0]
# Out:
# 561

# %%
explained_variance[0:50].shape
# Out:
# (50,)

# %%
#with plt.style.context('dark_background'):
plt.figure(figsize=(6, 4))
plt.bar(range(explained_variance[0:50].shape[0]), explained_variance[0:50], alpha=0.5, align='center',
        label='individual explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.tight_layout()

# %%
#pca = PCA(n_components=5)
#X = pca.fit_transform(X)
X.shape
# Out:
# (2947, 561)

# %%
#splitting train and test data
from sklearn.model_selection import train_test_split

#train, test model split

### Some classification problems do not have a balanced number of examples for each class label. As such,
### it is desirable to split the dataset into train and test sets in a way that preserves the same proportions of 
### examples in each class as observed in the original dataset.
### We can achieve this by setting the “stratify” argument to the y component of the original dataset.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,stratify=y)
print(X_train.shape, X_test.shape, y_train.shape,y_test.shape)


#scaling the independent variable
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# (2357, 561) (590, 561) (2357,) (590,)

# %%
models = {"Logistic Regression": LogisticRegression(),
          
          # ensemble models
          "RandomForestClassifier":RandomForestClassifier(),
        'SupportVectorMachine' : SVC(),
         # 'AdaBoostClassifier' : AdaBoostClassifier(),
          
          ## tree based classifiers
          "DecisionTreeClassifier":DecisionTreeClassifier(),
         # "ExtratreeClassifier" :ExtraTreesClassifier()
         }

# %%
parameters = {
        ## gradient descent based models 
        "Logistic Regression": {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']},
          
          # Ensemble models
          "RandomForestClassifier":{'n_estimators': [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)],
                                  #'max_features':['auto', 'sqrt'],
                                   'max_depth':[2,4],
                                    #'min_samples_split': [2, 5],
                                   #'min_samples_leaf': [1,2,3,4],
                                   'bootstrap': [True, False]},
              
          'SupportVectorMachine' : {'C':[0.125, 0.5, 1, 2, 8, 16]},
          #'AdaBoostClassifier' : AdaBoostClassifier(),
          
          ## tree based classifiers
          "DecisionTreeClassifier":{ 'max_depth': np.arange(3,5,1)}
         # "ExtratreeClassifier" :ExtraTreesClassifier()
         }

# %%
score_model =[]
labels =['Laying','Sitting','Standing','Walking','Walking_Downstairs','Walking_Upstairs']

for i in range(len([*models])):
    model = RandomizedSearchCV(estimator = models[[*models][i]], param_distributions = parameters[[*models][i]], cv = 10, verbose=0, n_jobs = 4)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    lst = [[*models][i], model.best_params_, accuracy_score(y_test,y_pred).round(2), 
      f1_score(y_test, y_pred, average="macro").round(2),
      recall_score(y_test,y_pred,average ='macro').round(2),  #options for average [None, 'micro', 'macro', 'weighted'].
      precision_score(y_test,y_pred,average ='macro').round(2)]

    score_model.append(lst)
    
    cm  =pd.DataFrame(confusion_matrix(y_true=y_test, y_pred= y_pred))
    fig,ax = plt.subplots()
    plt.figure(figsize=(1.5, 1.5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu",ax=ax)
    ax.set_title(f"Confusion Matrix {[*models][i]}")
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.xaxis.set_ticklabels(labels,rotation =90)
    ax.yaxis.set_ticklabels(labels,rotation =0)
    plt.show()


pd.DataFrame(score_model,columns =['Model','Best_params','Accuracy','F1_score','Recall','Precision'])
# Out:
# C:\Users\hornt\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 60 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\hornt\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hornt\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

model =DecisionTreeClassifier()
model.fit(X_train,y_train)

# Plot the decision tree
#plt.figure(figsize=(10, 8))
plot_tree(model, filled=True, feature_names=list(data.iloc[:,:-2].columns), class_names=labels)
plt.show()

# %% [markdown]
# ### Model Selection using Cross Val Scores

# %%
scorings =['accuracy','balanced_accuracy']
#define a dataframe 
CrossVal_Test =pd.DataFrame( columns=['Model','accuracy','balanced_accuracy'])

def score_models(model_name, model,i):   
    score_lst =[]
    score_lst.append(model_name)
    for j in range(len(scorings)):
        score = cross_val_score(model, X, y, cv=5, scoring= scorings[j])
        #     print("{} average: {}".format(model_name, score.mean()))
        score_lst.append(score.mean())
    CrossVal_Test.loc[i] =score_lst

# %%
models = {"Logistic Regression": LogisticRegression(max_iter =1000),
          
          # ensemble models
          "RandomForestClassifier":RandomForestClassifier(),
        'SupportVectorMachine' : SVC(),
          'AdaBoostClassifier' : AdaBoostClassifier(),
          
          ## tree based classifiers
          "DecisionTreeClassifier":DecisionTreeClassifier(criterion="entropy", max_depth = 4),
          "ExtratreeClassifier" :ExtraTreesClassifier()
         }

for i in range(len([*models])):
    score_models([*models][i],models[[*models][i]],i)

CrossVal_Test.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[151], line 14
#       1 models = {"Logistic Regression": LogisticRegression(max_iter =1000),
#       2
#       3           # ensemble models
#    (...)
#      10           "ExtratreeClassifier" :ExtraTreesClassifier()
#      11          }
#      13 for i in range(len([*models])):
# ---> 14     score_models([*models][i],models[[*models][i]],i)
#      16 CrossVal_Test.head(10)
#
# Cell In[81], line 9, in score_models(model_name, model, i)
#       7 score_lst.append(model_name)
#       8 for j in range(len(scorings)):
# ----> 9     score = cross_val_score(model, X, y, cv=5, scoring= scorings[j])
#      10     #     print("{} average: {}".format(model_name, score.mean()))
#      11     score_lst.append(score.mean())
#
# ...

# %% [markdown]
# ### ANN Classification

# %%
y_train.unique()
# Out:
# array([1, 6, 3, 5, 2, 4], dtype=int64)

# %%
from tensorflow import keras

# %%
output_cat = len(y.unique())
feature_columns = X_train.shape[1]
print(feature_columns)
# Out:
# 561

# %%
## model.add(keras.layers.Dense(units=64,kernel_initializer='normal',activation='sigmoid',input_dim=X_train.shape[1]))
model = keras.Sequential([
    keras.layers.Dense(input_shape=(feature_columns,),units = output_cat+1,  activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train,y_train, epochs=100,validation_data = (X_test,y_test))
# Out:
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1578 - loss: 1.9148 - val_accuracy: 0.2593 - val_loss: 1.7488
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2153 - loss: 1.7680 - val_accuracy: 0.3153 - val_loss: 1.7134
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2519 - loss: 1.7314 - val_accuracy: 0.3559 - val_loss: 1.6777
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3346 - loss: 1.6835 - val_accuracy: 0.4814 - val_loss: 1.6364
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3905 - loss: 1.6443 - val_accuracy: 0.3492 - val_loss: 1.6318
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4365 - loss: 1.6031 - val_accuracy: 0.3983 - val_loss: 1.5969
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4715 - loss: 1.5707 - val_accuracy: 0.5203 - val_loss: 1.5462
# Epoch 8/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9832 - loss: 0.2479
# [0.259550541639328, 0.9796609878540039]

# %%
yp = model.predict(X_test)
yp.shape
yp[0]
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([1.3529499e-05, 2.0500477e-01, 2.3430750e-01, 2.0373739e-01,
#        5.8545017e-01, 3.4923789e-01, 9.3383908e-01], dtype=float32)

# %%
np.argmax(yp[0])
# Out:
# 6

# %%
y_pred=[]
for i in range(len(yp)):
    y_pred.append(np.argmax(yp[i]))
len(y_pred)
# Out:
# 590

# %%
cm =pd.DataFrame(confusion_matrix(y_true =y_test,y_pred =y_pred))
fig,ax =plt.subplots()
sns.heatmap(cm,annot =True ,fmt ='0.0f',ax =ax)
ax.set_xlabel('Predicted',color ='red',size =15)
ax.set_ylabel('Actual',color ='red',size =15)
ax.xaxis.set_ticklabels(labels,rotation =45)
ax.yaxis.set_ticklabels(labels,rotation =0)
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(input_shape=(feature_columns,), units = output_cat+1,  activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1571 - loss: 2.1958
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1933 - loss: 2.0586
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1942 - loss: 1.9539
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1849 - loss: 1.8521
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1961 - loss: 1.7940
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2199 - loss: 1.7693
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2388 - loss: 1.7605
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2224 - loss: 1.7521
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2215 - loss: 1.7413
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2646 - loss: 1.7314
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2893 - loss: 1.7170
# Epoch 12/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8703 - loss: 0.6440
# [0.6425309777259827, 0.8745762705802917]

# %%
yp = model.predict(X_test)
yp.shape
yp[0]
y_pred=[]
for i in range(len(yp)):
    y_pred.append(np.argmax(yp[i]))
len(y_pred)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 590

# %%
cm =pd.DataFrame(confusion_matrix(y_true =y_test,y_pred =y_pred))
fig,ax =plt.subplots()
sns.heatmap(cm,annot =True ,fmt ='0.0f',ax =ax)
ax.set_xlabel('Predicted',color ='red',size =15)
ax.set_ylabel('Actual',color ='red',size =15)
ax.xaxis.set_ticklabels(labels,rotation =45)
ax.yaxis.set_ticklabels(labels,rotation =0)
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.93      0.89       107
#            2       0.99      0.81      0.89        98
#            3       0.92      0.94      0.93       108
#            4       0.76      0.89      0.82        99
#            5       0.89      0.89      0.89        84
#            6       0.89      0.78      0.83        94
#
#     accuracy                           0.87       590
#    macro avg       0.88      0.87      0.87       590
# weighted avg       0.88      0.87      0.87       590
